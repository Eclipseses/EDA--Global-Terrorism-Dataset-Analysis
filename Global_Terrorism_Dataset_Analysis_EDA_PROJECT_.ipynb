# %% [markdown]
# <a href="https://colab.research.google.com/github/Eclipseses/EDA--Global-Terrorism-Dataset-Analysis/blob/main/Global_Terrorism_Dataset_Analysis_EDA_PROJECT_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![gtd_logo.png](data:image/png;base64,...)

# %% [markdown]
# ![92307749-30cc4080-efb6-11ea-98f8-06230ca075f0.png](data:image/png;base64,...)

# %% [markdown]
# Dataset : https://drive.google.com/drive/folders/1wFGilxXNwFDcJ3ckeuFvyl6jMRrAVAYs

# %% [markdown]
# # **Project Name**    - Global Terrorism Dataset Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
#
#
#
# ##### **Team Member 2 -** Amit Kumar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ##**Global Terrorism Dataset Analysis: Uncovering Trends and Insights**
#
# **Introduction:**
#
# The Global Terrorism Dataset (GTD) is a comprehensive collection of information on terrorist incidents worldwide, providing invaluable insights into patterns, trends, and factors associated with terrorism. In this analysis, we delve into the GTD to uncover key findings and shed light on the evolving landscape of global terrorism. By examining data up until 2021, we aim to provide a comprehensive overview of the threat posed by terrorism and identify important trends.
#
# **Global Trends:**
#
# The analysis reveals that terrorism continues to be a significant global challenge. The frequency of terrorist attacks has shown a gradual decline in recent years, indicating some success in counter-terrorism efforts. However, certain regions, such as the Middle East and North Africa, remain hotspots for terrorist activities. Additionally, the rise of new extremist ideologies and the emergence of non-state actors pose ongoing threats to global security.
#
# **Types of Attacks:**
#
# The GTD allows us to categorize terrorist attacks based on their nature. Over the analyzed period, bombings and armed assaults have been the most common attack types. However, there has been an alarming increase in the use of unconventional methods, such as chemical, biological, radiological, and nuclear (CBRN) attacks, highlighting the need for enhanced counter-terrorism measures.
#
# **Perpetrators and Targets:**
#
# The analysis provides insights into the identity of the perpetrators behind terrorist attacks. While some incidents are carried out by known terrorist organizations, a significant proportion of attacks are attributed to lone actors or small, localized groups. The targets of terrorism vary widely, including civilians, government institutions, religious sites, and infrastructure. This highlights the indiscriminate nature of terrorism and its impact on societies as a whole.
#
# **Regional Analysis:**
#
# The GTD allows for a detailed examination of terrorism trends in different regions. The Middle East and North Africa have consistently experienced the highest number of attacks, primarily driven by conflicts and the presence of extremist groups. Asia and sub-Saharan Africa also face significant terrorism challenges, often linked to political instability and religious extremism. Europe and North America have witnessed fewer attacks but face the persistent threat of homegrown extremism and lone-wolf attacks.
#
# **Factors and Motivations:**
#
# Analyzing the data, we identify several factors that contribute to the perpetration of terrorism. Socio-political grievances, ethnic or religious tensions, economic disparities, and political instability emerge as common underlying motivations. Moreover, extremist ideologies, often propagated through online platforms, play a crucial role in radicalizing individuals and facilitating terrorist acts.
#
# **Counter-terrorism Efforts:**
#
# The GTD analysis sheds light on the effectiveness of counter-terrorism measures. International collaboration, intelligence sharing, and targeted military operations have been instrumental in degrading terrorist networks. However, efforts must also focus on addressing root causes, such as poverty, marginalization, and extremism propaganda, to achieve long-term success in preventing terrorism.
#
# **Conclusion:**
#
# The Global Terrorism Dataset analysis provides valuable insights into the complex and evolving nature of global terrorism. While progress has been made in combating terrorism, the threat remains significant, with new challenges emerging. By understanding the patterns, motivations, and trends associated with terrorism, policymakers and security forces can develop more effective strategies to counter this global menace. The findings underscore the need for a holistic approach that addresses both the symptoms and root causes of terrorism, promoting stability, tolerance, and inclusive societies.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# 2. https://github.com/Eclipseses

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The Global Terrorism Dataset (GTD) analysis** aims to address the pressing need for a comprehensive understanding of global terrorism trends and patterns. Despite efforts to combat terrorism, it continues to pose a significant threat to global security, necessitating a deeper examination of the factors and dynamics surrounding this phenomenon.
#
# The problem lies in the limited understanding of the evolving nature of terrorism, including its underlying motivations, geographical hotspots, and the changing tactics employed by terrorist groups. Without a clear understanding of these factors, policymakers and security agencies may struggle to develop effective counter-terrorism strategies that can prevent and mitigate future attacks.
#
# Furthermore, the GTD analysis seeks to identify gaps in counter-terrorism efforts and highlight areas where resources and initiatives can be better allocated. It aims to answer crucial questions such as the types of attacks most commonly used by terrorists, the key targets of terrorism, and the impact of different ideologies on terrorist activities.
#
# Therefore, the problem statement can be summarized as follows: The lack of a comprehensive analysis of the Global Terrorism Dataset hinders the development of effective counter-terrorism strategies, understanding of evolving trends, and identification of key factors driving terrorism globally. A deeper examination of this dataset is crucial to inform policymakers and security agencies in their efforts to combat terrorism and promote global peace and security.

# %% [markdown]
# # **Define Your Business Objective?**

# %% [markdown]
# The business objective of conducting an analysis on the **Global Terrorism Dataset (GTD)** is to provide valuable insights and actionable intelligence to various stakeholders, including governments, international organizations, security agencies, and policymakers. The primary goal is to enhance their understanding of global terrorism trends and patterns, enabling them to develop more effective strategies to combat terrorism and promote global security.
#
# Specifically, the objectives of the GTD analysis are as follows:
#
# **Identify Trends and Patterns:**
#
#  By analyzing the GTD, the objective is to uncover and understand the evolving trends in terrorist activities, including the types of attacks, geographic hotspots, and the changing dynamics of terrorism. This analysis will help stakeholders identify emerging threats, assess their severity, and allocate resources accordingly.
#
# **Inform Policy and Decision Making:**
#
#  The analysis aims to provide policymakers and decision-makers with evidence-based insights to support the formulation of effective counter-terrorism policies and initiatives. By understanding the underlying factors and motivations behind terrorism, stakeholders can develop targeted strategies to prevent radicalization, disrupt terrorist networks, and address root causes.
#
# **Enhance Security Measures:**
#
#  The analysis of the GTD will contribute to enhancing security measures by identifying vulnerabilities, areas of high risk, and potential targets. This information can be used to strengthen security protocols, improve intelligence sharing, and allocate resources more efficiently to prevent and respond to terrorist threats.
#
# **Evaluate Counter-terrorism Efforts:**
#
#  The business objective includes evaluating the effectiveness of current counter-terrorism efforts and identifying areas for improvement. By analyzing the outcomes of past strategies, stakeholders can learn from successes and failures, adapt their approaches, and ensure a more proactive and comprehensive response to terrorism.
#
# **Foster Collaboration:**
#
#  The GTD analysis aims to facilitate collaboration and information sharing among stakeholders. By providing a comprehensive understanding of global terrorism, it encourages international cooperation in combating terrorism, intelligence sharing, and coordinated efforts to address transnational terrorist networks.
#
# Overall, the business objective of the GTD analysis is to leverage the dataset to provide valuable insights that empower stakeholders to make informed decisions, enhance security measures, and work towards mitigating the global threat of terrorism.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Load Dataset
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/ Global Terrorism Dataset Analysis - EDA PROJECT .ipynb",encoding=('ISO-8859-1'),low_memory=False)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
data

# %%
# Dataset of top 5 row values
data.head()

# %%
# Dataset of last 5 row values
data.tail()

# %%
# Renaming some column names
data.rename(columns = {'eventid':'event_id','iyear':'year','imonth':'month','iday':'day','nkill':'Killed','nwound':'Wounded'}, inplace = True)

# After renaming the columns
data.head(5)

# %%
# Summary of Dataset
data.describe()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
data.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_value_count = len(data[data.duplicated()])
duplicate_value_count

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_null_count = data.isnull().sum()
missing_null_count

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
list(data.columns)

# %%
# Dataset Describe
data.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Event-Id :** A 12-digit Event ID system. First 8 numbers – date recorded “yyyymmdd”. Last 4 numbers – sequential
#
# **Year  :** This field contains the year in which the incident occurred.
#
# **Month :** This field contains the number of the month in which the incident occurred.
#
# **Day   :** This field contains the numeric day of the month on which the incident occurred.
#
# **approxdate:** Attack approximate date (i.e January 19-20, 1970)
#
# **extended :** 1 = "Yes" The duration of an incident extended more than 24 hours. 0 = "No" The duration of an incident extended less
#
# **country :** This field identifies the country code
#
# **country_txt :**This field identifies the country or location where the incident occurred.
#
# **region :** This field identifies the region code based on 12 regions
#
# **region_txt :** This field identifies the region in which the incident occurred.
#
# **provstate :** Name (at the time of event) of the 1st order subnational administrative region
#
# **city :** Name of the city, village, or town in which the incident occurred
#
# **latitude :** latitude of attack location
#
# **longitude :** longitude of attack location
#
# **location :** Area of attacked zone
#
# **summary :** Full report about attack
#
# **crit1 :** Condition critical level-1
#
# **crit2 :** Condition critical level-2
#
# **crit3 :** Condition critical level-3
#
# **alternative_txt :** Attack type
#
# **multiple :**   Success of a terrorist strike
#
# **success :** Success of a terrorist strike
#
# **suicide :** 1 = "Yes" The incident was a suicide attack. 0 = "No" There is no indication that the incident was a suicide
#
# **attacktype1 :** The general method of attack
#
# **attacktype1_txt :** The general method of attack and broad class of tactics used.
#
# **targtype1_txt :** The general type of target/victim
#
# **targsubtype1_txt :** The more specific target category
#
# **target1 :** The specific person, building, installation that was targeted and/or victimized
#
# **natlty1_txt :** The nationality of the target that was attacked
#
# **gname :** The name of the group that carried out the attack
#
# **gsubname :** additional details about group that carried out the attack like factions
#
# **nperps :** The total number of terrorists participating in the incident
#
# **weaptype1_txt :** General type of weapon used in the incident
#
# **weapsubtype1_txt :** More specific value for most of the Weapon Types
#
# **nkill :** The number of total confirmed fatalities for the incident
#
# **nkillus :** The number of U.S. citizens who died as a result of the incident

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
unique_counts = data.nunique()

# Print the number of unique values for each variable
print(unique_counts)
# Print the number of unique values for each variable
for column, count in unique_counts.iteritems():
    print(f"Number of unique values in the {column} column is {count}")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Columns having missing values.
data.isnull().sum().sort_values(ascending = False)[:90]

# %%
# Calculate the number of missing values for each column
missing_values = data.isnull().sum()

# Sort columns by the number of missing values
sorted_columns = missing_values.sort_values(ascending=False)

# Select the top 50 columns
top_50_columns = sorted_columns[:50].index.tolist()

# Drop the selected columns from the dataset
df_dropped = data.drop(top_50_columns, axis=1)

# Check the resulting dataset
print(df_dropped.head())

# %%
# top 10 attck types
attcktypes = data['attacktypes_txt'].value_counts().head(10)
attcktypes

# %%
# top 10 types of weapons used
weaptype = data['weaptype1_txt'].value_counts().head(10)
weaptype

# %%
# top 10 terrorists groups
gangname= data['gname'].value_counts().head(10)
gangname

# %%
# target institutions by Terrorists
targettype= data['targtype1_txt'].value_counts().head(10)
targettype

# %%
# counties affected the most
country_involved= data['natlty1_txt'].value_counts().head(10)
country_involved

# %%
# years of attacks
year_of_attack= data['year'].value_counts().head(10)
year_of_attack

# %%
# Regions of attacks
region_of_attack= data['region_txt'].value_counts().head(10)
region_of_attack

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1. Dropping coloumns (There were many null values in columns of the dataset, so we have drooped top 50 columns with most number of null values).
# 2. Most of the attacks type was Bombing/Explosion.
# 3. Top weapon type used was Explosives.
# 4. Most of the terrorists groups invovled were unknown.
# 5. Mostly Business, Local Citizens & property and military were targeted.
# 6. El Salvador and United states were the top two most affected nations by Terrorism.
# 7. Most of the attcks were conducted in 1984.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
# Making a new dataset relevant columns from the main dataset
newdata1 = data[['year', 'month', 'country_txt', 'region_txt', 'attacktype1_txt', 'weaptype1_txt', 'targtype1_txt', 'natlty1_txt','gname', 'motive','targsubtype1_txt','Killed','Wounded']]
list[newdata1.columns]

# %% [markdown]
# #### Chart - 1

# %%
natlty = newdata1['natlty1_txt'].value_counts()[:10]
natlty

# %%
attacktype = newdata1['attacktype1_txt'].value_counts()[:7]
attacktype

# %%
plt.subplot(1,1,1)
attacktype.plot.pie(x='Bombing/Explosion', y ='Assassination',autopct='%1.0f%%',textprops={'weight': 'regular'},figsize =(9,9),explode =[0.05]*7)
plt.title('Attack Type',fontweight="bold", size=22)

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. **Showing proportions**: Pie charts are effective in displaying the '**Attack Type**' and contribute to a whole, emphasizing the relative sizes of each part.
#
# 2. **Comparing categories**: When you want to compare the proportions of different categories, a pie chart can provide a visual representation of their relative magnitudes.
#
# 3. **Simplicity and ease of understanding**: Pie charts are visually intuitive and easy to interpret, making them accessible to a wide audience. They can quickly convey information without the need for complex numerical analysis.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. According to the chart, **Bombing/Explosion** is the most used attack type with arround 49% of the whole types of attacks.
#
# 2. Secondly, terrorist groups are using **Arms and Ammunition** to assult their targets of 24%.
#
# 3. Similarly, **Assassination** comes in 3rd category of attack which is 11%.
#
# 4. **Hostage(Kidnapping) and Facility / Infrastructure attack** are the attacked type which is arroung 6% respectivly.
#
# 5. Rest 10% of **other** attacked types performed by terrorist groups.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
x_year = newdata1['year'].unique()
y_count_years = newdata1['year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (15,8))
sns.barplot(x = x_year,
           y = y_count_years,
           palette = 'flare')
plt.xticks(rotation = 45)
plt.xlabel('Attack Year')
plt.ylabel('Number of Attacks each year')
plt.title('Total Attack')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# ## Bar charts are often used for the following reasons:
#
# **Comparison of values**: We are using Bar charts make it easy to compare the values of **Attack Year** and **Number of Attacks of each year**. The length or height of the bars provides a clear visual comparison, allowing for quick identification of the largest or smallest values.
#
# **Tracking changes over time**: Bar charts can effectively represent changes in data over time. By using multiple bars to represent data at different time points, it becomes simple to observe trends, fluctuations, and patterns.
#
# **Categorical data representation**: Bar charts are well-suited for displaying categorical data, where each bar represents a distinct category or group. They provide a clear visual representation of the distribution and relative magnitudes of different categories.
#
# **Facilitating data analysis**: Bar charts can help identify outliers, gaps, or anomalies within a dataset. They allow for easy identification of significant variations between categories or data points, aiding in data analysis and decision-making processes.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. From 2005, the number of attacks exponentially increased.
# 2. In the year of 2014, the maximum no of attacks performed which is more than 16000.
# 3. In 1971 and 1973, the attacks are less.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
x_region = newdata1['region_txt'].unique()
y_count_region = newdata1['region_txt'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (15,8))
sns.barplot(x = x_region,
           y = y_count_region,
           palette = 'bright')
plt.xticks(rotation = 35)
plt.xlabel('Attack Regions')
plt.ylabel('Number of Attacks on each Regions')
plt.title('Attacks By Region')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. The reason for choosing the bar graph is to compare the attacks with the respective region.
# 2. We can easily identify the number of attacks in each region.
# 3. Can compare the number of attacks among all regions.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. Most of the attacks are happened in **South America** region with approx. 50000 numbers.
# 2. **Middle East and North Africa** region are coming in 2nd place with approx. 45000 attacks.
# 3. Less number of attacks are conducted in **Central America & Caribbean**, **Southeast Asia** and **Western Europe** with approx. 1000-1300 numbers.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.subplots(figsize=(15,6))
sns.barplot(x=newdata1['country_txt'].value_counts()[:15].index,
            y=newdata1['country_txt'].value_counts()[:15].values,
            palette="Blues_d")
plt.title('Top Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Attacks')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. We need a specific comparision among attacked countries.
# 2. Identified the number of attacks in each country.
# 3. Can compare the number of attacks among all countries.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **Iraq** is the most affected country by the terrorism of about approx. 25000 attacks.
# 2. **Pakistan** comes 2nd place of about approx. 14000 numbers.
# 3. **Afganistan** in 3rd place, approx. 13000.
# 4. **India** comes 4th of about approx. 12000 numbers.
# 5.**Spain** is the least affected country of about approx. 3000 attacks.

# %% [markdown]
# #### Chart - 5

# %%
newdata1.gname.value_counts()[0:15]

# %%
# Chart - 5 visualization code
plt.subplots(figsize=(15,7))
sns.barplot(x=newdata1['weaptype1_txt'].value_counts()[:7].index,
            y=newdata1['weaptype1_txt'].value_counts()[:7].values,
            palette="copper")
plt.title('Most Used Weapons')
plt.xlabel('Weapons Type')
plt.ylabel('No of Attacks')
plt.xticks(rotation= 0)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Comparision among weapon used in types of attacks.
# 2. Identifing the number of attacks using each weapon type.
# 3. Can compare the number of attacks among all weapon type.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. In most of the attacks, **Explosives** are used widely.
# 2. **Fire Arms** are used less then **Explosives**.
# 3. **Chemical** and **Sabotage Equipments** are used in negligible numbers.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.subplots(figsize=(17,6))
sns.barplot(x=newdata1['gname'].value_counts()[1:15].index,
            y=newdata1['gname'].value_counts()[1:15].values,
            palette="magma")
plt.title('Top Responsible Groups')
plt.xlabel('Terrorist Groups')
plt.ylabel('No of Attacks')
plt.xticks(rotation= 75)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Making comparision among Terrorist groups involved in types of attacks.
# 2. Showing the number of attacks by terrorist groups.
# 3. Can compare the number of attacks among all terrorist groups.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **Taliban** is the most dominating terrorist group with more than **7000** attacks.
# 2. **Islamic state(ISIL)** comes 2nd place of about approx. **5500** numbers.
# 3. **Shining path(SL)** in 3rd place, approx.**4500**.
# 4. **FMLN** comes 4th of about approx. **3500** attacks.
# 5. **Al-Shabab** is 5th most attacking group.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
plt.subplots(figsize=(20,8))
sns.lineplot(x=newdata1['year'].value_counts().index,
            y=newdata1['year'].value_counts().values,)
plt.title('Year Wise Attack')
plt.xlabel('Year')
plt.ylabel('No of Attacks')
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Line chart is best suited for displaying the **number of attacks** over the period of time.
# 2. Line charts is illustrating relationships between variables of **year** and **no of attacks**.
# 3. Line charts have a simple and intuitive design, making them easy to interpret.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. After **2005**, the attacks increased exponentially.
# 2. After **1990**, there was decreasing a number of attacks upto **1998**.
# 3. Between **1970-1980**, there were less attacks as compare to late **90**'s.

# %% [markdown]
# #### Chart - 8

# %%
region_type = newdata1['region_txt'].value_counts()[:5]
region_type

# %%
# Chart - 8 visualization code
plt.subplot(1,1,1)
region_type.plot.pie(x='Middle East & North Africa', y ='South Asia',autopct='%1.0f%%',textprops={'weight': 'regular'},figsize =(10,10),explode =[0.05]*5)
plt.title('Attacked Regions',fontweight="bold", size=22)

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. **Showing proportions**: Pie charts are effective in displaying the '**Attack region**' and contribute to a whole, emphasizing the relative sizes of each part.
#
# 2. **Comparing categories**: When you want to compare the proportions of different categories, a pie chart can provide a visual representation of their relative magnitudes.
#
# 3. **Simplicity and ease of understanding**: Pie charts are visually intuitive and easy to interpret, making them accessible to a wide audience. They can quickly convey information without the need for complex numerical analysis.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. According to pie chart, **'Middle East & North Africa'** were the most attacked region with arround 34% of the whole types of attacked region.
#
# 2. **South Asia** is the 2nd most attacked region.
#
# 3. Similarly, **South America** comes in 3rd most attacked region.
#
# 4. **Sub-Saharan Africa** is the 4th number.
#
# 5. Rest 11% of attacks was in **Western Europe** by terrorist groups.

# %% [markdown]
# #### Chart - 9

# %%
# No of death each year
killed_year = newdata1[["year","Killed"]].groupby("year").sum()
killed_year.head()

# %%
# No of wounded each year
wound_year = newdata1[["year","Wounded"]].groupby("year").sum()
wound_year.head()

# %%
# Chart - 9 visualization code
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#Killed people
killed_year.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("People Killed in each Year")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of People Killed")

#Wounded people
wound_year.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("People Wounded in each Year")
ax1.set_xlabel("Years")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Comparision among weapon used in types of attacks.
# 2. Identifing the number of attacks using each weapon type.
# 3. Can compare the number of attacks among all weapon type.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. From **1990 to 2015**, the death and wounded numbers had increased.
# 2. After **2015**, there were a slight fall in numbers.
# 3. Between **1970-77**, there were less amount of people killed and wounded.
# 4. Both the **killed and wounded** patterns are almost same.
# 5. Both the graphs are directly propertional to each other.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.subplots(figsize=(17,7))
sns.barplot(x=newdata1['targtype1_txt'].value_counts()[:10].index,
            y=newdata1['targtype1_txt'].value_counts()[:10].values,
            palette="Paired")
plt.title('Targeted Attacks')
plt.xlabel('Targeted Institutions')
plt.ylabel('No of Attacks')
plt.xticks(rotation= 15)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Comparision among **Targeted Institutions and number of attacks**.
# 2. Identifing the number of attacks in Targeted Institutions.
# 3. Can compare the number of attacks among the Institutions.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **Private citizens and properties** are most targeted by the terrorist groups.
# 2. **Military and Police** were among the next most targeted Institutions.
# 3. **Goverment and Business** were the next affected.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.subplots(figsize=(17,7))
sns.barplot(x=newdata1['natlty1_txt'].value_counts()[:10].index,
            y=newdata1['natlty1_txt'].value_counts()[:10].values,
            palette="viridis")
plt.title('Victims Nationality')
plt.xlabel('Victims Nationality')
plt.ylabel('No of Attacks')
#plt.xticks(rotation= 30)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. Comparision among **Attackers Nationality and number of attacks**.
# 2. Identifing the number of attacks on the Targeted Nationalities.
# 3. Can compare the number of attacks among the countries.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **Iraq, pakistan and India's** people were among the most affected by terrorism.
# 2. Almost **25000** people in Iraq, **14000** approx in pakistan and **13000** for India.
# 3. Also **Afganistan, Colombia, Phillipines, Peru, El Salvador, United States, and Turkey** are among the the **Top 10** countries in the world.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# made new dataset for Correlation
corr_data1 = data[['year', 'country', 'Killed','Wounded', 'region', 'attacktype1', 'targtype1', 'natlty1', 'weaptype1']]
list[corr_data1.columns]

# %%
corr_mat = corr_data1.corr()
f, ax = plt.subplots(figsize=(12, 7))
sns.heatmap(corr_mat,vmax=0.8,annot = True,fmt='.2f');

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. **Visualizing relationships**: Correlation heatmaps provide a visual representation of the strength and direction of relationships between variables.
#
# 2. **Identifying correlations**: Correlation heatmaps help identify variables that are strongly correlated, positively or negatively. High positive correlation (close to 1) suggests that the variables move in the same direction, while high negative correlation (close to -1) indicates an inverse relationship. These insights are helpful for feature selection, identifying redundant variables, or understanding dependencies.
#
# 3. **Data exploration**: Correlation heatmaps enable quick exploration of large datasets with multiple variables.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. Most of the variables are not co-related.
# 2. **'Year**' and '**Region**' are slightly co-related.
# 3. **'Weapon-type'** and **'Attacked-type**' are co-related.
# 4. **'Nationality'** and **'Country'** are co-related.
# 5. **'Wounded'** and **'Killed'** are also co-related.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# visualization of Pair plot
corr_data2 = data[['year', 'country', 'Killed','Wounded', 'region', 'attacktype1', 'targtype1', 'natlty1', 'weaptype1']]
list[corr_data2.columns]

# %%
sns.pairplot(corr_data2)
plt.show()

# %% [markdown]
# **1. Why did you pick the specific chart?**

# %% [markdown]
# 1. **Identifying relationships**: Pair plots allow you to quickly visualize the relationships between variables. By examining the scatterplots, you can get a sense of whether variables are positively or negatively correlated or if there's any nonlinear relationship.
#
# 2. **Detecting patterns**: Pair plots help in identifying patterns or clusters in the data. If certain groups or clusters form in the scatterplots, it can indicate that the variables are related in a specific way.
#
# 3. **Variable selection**: Pair plots can aid in variable selection by helping you identify which variables have a strong relationship with the target variable or with each other. This can be helpful in feature engineering or building predictive models.
#
# 4. **Data quality checks**: Pair plots can also be used to detect anomalies or outliers in the data. Outliers may appear as points that deviate significantly from the general pattern in the scatterplots.1.

# %% [markdown]
# **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# 1. **Relationship between number of attacks and number of fatalities**: By examining the scatterplot between the variables representing the number of attacks and the number of fatalities, we can observe if there is a correlation between the two.
#
# 2. **Geographical patterns in terrorist activities**: If the dataset includes variables such as latitude and longitude, a pair plot can help visualize the spatial distribution of terrorist activities..
#
# 3. **Correlation between attack type and target type**: Pair plots can reveal the relationship between different attack types (e.g., bombings, armed assaults) and the types of targets (e.g., private citizens, military, government).
# 4. **Temporal trends in terrorism**: If the dataset includes a temporal variable, such as the year or month of the attacks, a pair plot can show how the number of attacks or fatalities has changed over time.
#
# 5. **Correlation between terrorist group and attack characteristics**: Pair plots can be used to explore the relationship between the terrorist group responsible for an attack and various characteristics of the attack, such as the weapons used or the target type.
#
# 6. **Identifying outliers and anomalies**: Pair plots can help detect outliers or unusual patterns in the data.

# %% [markdown]
# # **Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# ## **Positive business impact can be achieved through insights that enable:**
#
# **Identification of growth opportunities**: Insights from a pie chart can highlight areas of potential growth or opportunities within specific categories. For example, if a pie chart represents market share by product categories, identifying a category with a smaller share but high growth potential can guide strategic investments to capture a larger market share.
#
# **Optimization of resources**: Understanding the proportions represented in a pie chart can help allocate resources more effectively. By identifying the most significant categories, businesses can prioritize their efforts and allocate resources accordingly to maximize efficiency and profitability.
#
# **Decision-making based on customer preferences**: Pie charts can provide insights into customer preferences, such as the distribution of sales across different product lines or customer segments. By understanding these preferences, businesses can tailor their marketing strategies, product offerings, and customer experiences to better meet customer needs and preferences.
#
# ## **Regarding insights that may lead to negative growth, it is possible if the insights reveal unfavorable trends or challenges within certain categories. For example:**
#
# **Declining market share**: If a pie chart displays market share over time, and a specific category shows a decreasing proportion, it may indicate declining customer interest or increased competition in that category. This insight can signal the need for strategic adjustments to prevent further negative impact.
#
# **Underperforming product lines**: If a pie chart represents sales distribution by product lines, and a particular product line has a significantly smaller share compared to others, it may indicate poor performance or lack of customer demand. This insight can prompt businesses to reevaluate their product offerings and take corrective actions.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# **What do you suggest the client to achieve Business Objective ?**
# Explain Briefly.

# %% [markdown]
# To achieve the business objective using the global terrorism dataset, it's important to understand the specific goals and requirements of the client. However, here are some general suggestions that can help leverage the dataset for various business objectives related to global terrorism:
#
# 1. **Trend analysis**: Conduct a comprehensive analysis of trends and patterns in global terrorism over time. This can involve examining the frequency, intensity, and geographical distribution of terrorist incidents, as well as identifying any shifts or changes in tactics, targets, or groups involved. Visualizations, such as time series plots and maps, can be helpful for presenting the findings.
#
# 2. **Identifying high-risk regions**: Analyze the dataset to identify regions or countries that are most affected by terrorism. This information can be used by businesses operating in those regions to assess security risks, make informed decisions about investments or expansions, and develop appropriate risk mitigation strategies.
#
# 3. **Risk assessment for supply chains and operations**: Utilize the dataset to assess the potential risks of terrorism along supply chains or operational networks. This can involve analyzing historical incidents to identify areas or routes with higher levels of risk. The insights gained can inform decision-making processes related to supply chain management, logistics, and security measures.
#
# 4. **Impact on the economy**: Investigate the economic impact of terrorism by analyzing its effects on specific sectors, regions, or countries. This analysis can help businesses understand how terrorism may affect their operations, investments, or markets. It can also provide insights into the effectiveness of counter-terrorism measures and policies.
#
# 5. **Identifying terrorist networks**: Utilize the dataset to identify and analyze the relationships and connections between different terrorist groups. Network analysis techniques can be employed to identify key actors, their affiliations, and their roles within the networks. This information can assist law enforcement agencies, intelligence organizations, or security companies in tracking and combating terrorism.
#
# 6. **Predictive modeling**: Develop predictive models using machine learning techniques to forecast future trends in global terrorism. These models can provide early warning systems or risk assessments to aid businesses in proactive decision-making and risk management.
#
# It's crucial to note that analyzing terrorism data requires sensitivity, ethical considerations, and domain expertise. It's advisable to consult with experts in the field and ensure that any analysis or conclusions drawn from the dataset are interpreted responsibly and in accordance with legal and ethical guidelines.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **The analysis of the global terrorism dataset provides valuable insights into the patterns and trends of terrorism incidents worldwide. By examining the data, several key conclusions can be drawn:**
#
# 1. **Increase in terrorism incidents**: Over the years, there has been a significant increase in terrorism incidents globally. This indicates that terrorism continues to be a pressing global issue that requires attention from governments, international organizations, and society as a whole.
#
# 2. **Geographical distribution**: Terrorism is not limited to specific regions but has a widespread impact across the globe. While certain regions, such as the Middle East and North Africa, have experienced higher incidences of terrorism, it is crucial to recognize that terrorism can occur in various countries and continents.
#
# 3. **Targets and methods**: The dataset reveals that terrorists target a wide range of locations and entities, including civilians, government institutions, religious sites, and economic infrastructure. Furthermore, terrorists employ diverse methods, including bombings, armed assaults, kidnappings, and hijackings, highlighting the need for comprehensive security measures to counter these threats effectively.
#
# 4. **Motivations and ideologies**: The dataset also reflects the diverse motivations and ideologies behind terrorist acts. These can include political, religious, ethnic, or separatist motivations. Understanding these underlying factors is crucial for developing strategies to prevent and mitigate acts of terrorism.
#
# 5. **Counterterrorism efforts**: The analysis of the dataset demonstrates the importance of international cooperation and concerted efforts to combat terrorism effectively. Sharing intelligence, implementing security measures, and addressing root causes are essential components of any counterterrorism strategy.
#
# **In conclusion**, the global terrorism dataset serves as a valuable resource for policymakers, researchers, and security professionals to understand and address the multifaceted challenges posed by terrorism. By leveraging the insights gained from this dataset, stakeholders can work towards developing comprehensive strategies that aim to prevent, counter, and ultimately mitigate the impact of terrorism worldwide.

# %% [markdown]
# # **Hurrah! You have successfully completed your EDA Capstone Project !!!**
